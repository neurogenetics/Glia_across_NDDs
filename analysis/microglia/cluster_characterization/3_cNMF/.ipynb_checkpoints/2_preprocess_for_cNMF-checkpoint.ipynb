# %%
import os
import pandas as pd
import numpy as np
from scipy.io import mmread
import scipy.sparse as sp
import matplotlib.pyplot as plt
from IPython.display import Image
import scanpy as sc
from cnmf import cNMF, Preprocess
import anndata
import seaborn as sns

# %%
adata = sc.read_h5ad("/data/ADRD/glia_across_NDDs/analysis/microglia/cluster_characterization/cNMF/microglia_cNMF.h5ad")

# %%
# transfer raw counts to new objects to be processsed by scanpy
adata_new = anndata.AnnData(X=adata.X, obs=adata.obs.copy(), var=adata.var.copy())

# %%
# batch correction
p = Preprocess(random_seed=14)
(adata_c, adata_tp10k, hvgs) = p.preprocess_for_cnmf(adata_new, harmony_vars=['dataset', 'donor'], n_top_rna_genes=2000,
                                                     max_scaled_thresh=None, quantile_thresh=.9999, makeplots=True, 
                                                     save_output_base='/data/ADRD/glia_across_NDDs/analysis/microglia/cluster_characterization/cNMF')
# Out:
# /home/horanportelanlj/.local/lib/python3.10/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/horanportelanlj/.local/lib/python3.10/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# 2025-04-01 13:19:03,890 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-04-01 13:19:07,236 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2025-04-01 13:19:07,337 - harmonypy - INFO - Iteration 1 of 20
# 2025-04-01 13:19:25,315 - harmonypy - INFO - Iteration 2 of 20
# 2025-04-01 13:19:43,275 - harmonypy - INFO - Iteration 3 of 20
# 2025-04-01 13:20:01,556 - harmonypy - INFO - Iteration 4 of 20
# 2025-04-01 13:20:19,960 - harmonypy - INFO - Iteration 5 of 20
# 2025-04-01 13:20:37,867 - harmonypy - INFO - Iteration 6 of 20
# ...
